# %% [markdown]
# <a href="https://www.kaggle.com/code/singhayush16/predict-co2-emissions-in-rwanda?scriptVersionId=140359293" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/playground-series-s3e20/sample_submission.csv
# /kaggle/input/playground-series-s3e20/train.csv
# /kaggle/input/playground-series-s3e20/test.csv

# %% [markdown]
# # **Training Part**

# %%
train=pd.read_csv('/kaggle/input/playground-series-s3e20/train.csv')
train.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                       -0.000065
# 1                                        0.000014
# 2                                        0.000385
# 3                                             NaN
# 4                                       -0.000048
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.255668                           -98.593887  ...
# 1                       0.130988                            16.592861  ...
# 2                       0.110018                            72.795837  ...
# 3                            NaN                                  NaN  ...
# 4                       0.121164                             4.121269  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0             3664.436218               61085.809570              2615.120483
# 1             3651.190311               66969.478735              3174.572424
# 2             4216.986492               60068.894448              3516.282669
# 3             5228.507736               51064.547339              4180.973322
# 4             3980.598120               63751.125781              3355.710107
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                  15.568533              0.272292
# 1                   8.690601              0.256830
# 2                  21.103410              0.251101
# 3                  15.386899              0.262043
# 4                   8.114694              0.235847
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                  -12.628986                  35.632416
# 1                   30.359375                  39.557633
# 2                   15.377883                  30.401823
# 3                  -11.293399                  24.380357
# 4                   38.532263                  37.392979
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                -138.786423                 30.752140  3.750994
# 1                -145.183930                 27.251779  4.025176
# 2                -142.519545                 26.193296  4.231381
# 3                -132.665828                 28.829155  4.305286
# 4                -141.509805                 22.204612  4.347317
#
# [5 rows x 76 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
#  8   SulphurDioxide_cloud_fraction                             64414 non-null  float64
#  9   SulphurDioxide_sensor_azimuth_angle                       64414 non-null  float64
#  10  SulphurDioxide_sensor_zenith_angle                        64414 non-null  float64
#  11  SulphurDioxide_solar_azimuth_angle                        64414 non-null  float64
#  12  SulphurDioxide_solar_zenith_angle                         64414 non-null  float64
#  13  SulphurDioxide_SO2_column_number_density_15km             64414 non-null  float64
#  14  CarbonMonoxide_CO_column_number_density                   76901 non-null  float64
#  15  CarbonMonoxide_H2O_column_number_density                  76901 non-null  float64
#  16  CarbonMonoxide_cloud_height                               76901 non-null  float64
#  17  CarbonMonoxide_sensor_altitude                            76901 non-null  float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       76901 non-null  float64
#  19  CarbonMonoxide_sensor_zenith_angle                        76901 non-null  float64
#  20  CarbonMonoxide_solar_azimuth_angle                        76901 non-null  float64
#  21  CarbonMonoxide_solar_zenith_angle                         76901 non-null  float64
#  22  NitrogenDioxide_NO2_column_number_density                 60703 non-null  float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    60703 non-null  float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   60703 non-null  float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           60703 non-null  float64
#  26  NitrogenDioxide_tropopause_pressure                       60703 non-null  float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   60703 non-null  float64
#  28  NitrogenDioxide_cloud_fraction                            60703 non-null  float64
#  29  NitrogenDioxide_sensor_altitude                           60703 non-null  float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      60703 non-null  float64
#  31  NitrogenDioxide_sensor_zenith_angle                       60703 non-null  float64
#  32  NitrogenDioxide_solar_azimuth_angle                       60703 non-null  float64
#  33  NitrogenDioxide_solar_zenith_angle                        60703 non-null  float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      71746 non-null  float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  71746 non-null  float64
#  36  Formaldehyde_HCHO_slant_column_number_density             71746 non-null  float64
#  37  Formaldehyde_cloud_fraction                               71746 non-null  float64
#  38  Formaldehyde_solar_zenith_angle                           71746 non-null  float64
#  39  Formaldehyde_solar_azimuth_angle                          71746 non-null  float64
#  40  Formaldehyde_sensor_zenith_angle                          71746 non-null  float64
#  41  Formaldehyde_sensor_azimuth_angle                         71746 non-null  float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    78484 non-null  float64
#  43  UvAerosolIndex_sensor_altitude                            78484 non-null  float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       78484 non-null  float64
#  45  UvAerosolIndex_sensor_zenith_angle                        78484 non-null  float64
#  46  UvAerosolIndex_solar_azimuth_angle                        78484 non-null  float64
#  47  UvAerosolIndex_solar_zenith_angle                         78484 non-null  float64
#  48  Ozone_O3_column_number_density                            78475 non-null  float64
#  49  Ozone_O3_column_number_density_amf                        78475 non-null  float64
#  50  Ozone_O3_slant_column_number_density                      78475 non-null  float64
#  51  Ozone_O3_effective_temperature                            78475 non-null  float64
#  52  Ozone_cloud_fraction                                      78475 non-null  float64
#  53  Ozone_sensor_azimuth_angle                                78475 non-null  float64
#  54  Ozone_sensor_zenith_angle                                 78475 non-null  float64
#  55  Ozone_solar_azimuth_angle                                 78475 non-null  float64
#  56  Ozone_solar_zenith_angle                                  78475 non-null  float64
#  57  UvAerosolLayerHeight_aerosol_height                       439 non-null    float64
#  58  UvAerosolLayerHeight_aerosol_pressure                     439 non-null    float64
#  59  UvAerosolLayerHeight_aerosol_optical_depth                439 non-null    float64
#  60  UvAerosolLayerHeight_sensor_zenith_angle                  439 non-null    float64
#  61  UvAerosolLayerHeight_sensor_azimuth_angle                 439 non-null    float64
#  62  UvAerosolLayerHeight_solar_azimuth_angle                  439 non-null    float64
#  63  UvAerosolLayerHeight_solar_zenith_angle                   439 non-null    float64
#  64  Cloud_cloud_fraction                                      78539 non-null  float64
#  65  Cloud_cloud_top_pressure                                  78539 non-null  float64
#  66  Cloud_cloud_top_height                                    78539 non-null  float64
#  67  Cloud_cloud_base_pressure                                 78539 non-null  float64
#  68  Cloud_cloud_base_height                                   78539 non-null  float64
#  69  Cloud_cloud_optical_depth                                 78539 non-null  float64
#  70  Cloud_surface_albedo                                      78539 non-null  float64
#  71  Cloud_sensor_azimuth_angle                                78539 non-null  float64
#  72  Cloud_sensor_zenith_angle                                 78539 non-null  float64
#  73  Cloud_solar_azimuth_angle                                 78539 non-null  float64
#  74  Cloud_solar_zenith_angle                                  78539 non-null  float64
#  75  emission                                                  79023 non-null  float64
# dtypes: float64(73), int64(2), object(1)
# memory usage: 45.8+ MB

# %%
train.isnull().sum()
# Out:
# ID_LAT_LON_YEAR_WEEK            0
# latitude                        0
# longitude                       0
# year                            0
# week_no                         0
#                              ...
# Cloud_sensor_azimuth_angle    484
# Cloud_sensor_zenith_angle     484
# Cloud_solar_azimuth_angle     484
# Cloud_solar_zenith_angle      484
# emission                        0
# Length: 76, dtype: int64

# %%
train=train.interpolate(method='linear', limit_direction='both')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 76 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  79023 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              79023 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            79023 non-null  float64
#  8   SulphurDioxide_cloud_fraction                             79023 non-null  float64
#  9   SulphurDioxide_sensor_azimuth_angle                       79023 non-null  float64
#  10  SulphurDioxide_sensor_zenith_angle                        79023 non-null  float64
#  11  SulphurDioxide_solar_azimuth_angle                        79023 non-null  float64
#  12  SulphurDioxide_solar_zenith_angle                         79023 non-null  float64
#  13  SulphurDioxide_SO2_column_number_density_15km             79023 non-null  float64
#  14  CarbonMonoxide_CO_column_number_density                   79023 non-null  float64
#  15  CarbonMonoxide_H2O_column_number_density                  79023 non-null  float64
#  16  CarbonMonoxide_cloud_height                               79023 non-null  float64
#  17  CarbonMonoxide_sensor_altitude                            79023 non-null  float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       79023 non-null  float64
#  19  CarbonMonoxide_sensor_zenith_angle                        79023 non-null  float64
#  20  CarbonMonoxide_solar_azimuth_angle                        79023 non-null  float64
#  21  CarbonMonoxide_solar_zenith_angle                         79023 non-null  float64
#  22  NitrogenDioxide_NO2_column_number_density                 79023 non-null  float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    79023 non-null  float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   79023 non-null  float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           79023 non-null  float64
#  26  NitrogenDioxide_tropopause_pressure                       79023 non-null  float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   79023 non-null  float64
#  28  NitrogenDioxide_cloud_fraction                            79023 non-null  float64
#  29  NitrogenDioxide_sensor_altitude                           79023 non-null  float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      79023 non-null  float64
#  31  NitrogenDioxide_sensor_zenith_angle                       79023 non-null  float64
#  32  NitrogenDioxide_solar_azimuth_angle                       79023 non-null  float64
#  33  NitrogenDioxide_solar_zenith_angle                        79023 non-null  float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      79023 non-null  float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  79023 non-null  float64
#  36  Formaldehyde_HCHO_slant_column_number_density             79023 non-null  float64
#  37  Formaldehyde_cloud_fraction                               79023 non-null  float64
#  38  Formaldehyde_solar_zenith_angle                           79023 non-null  float64
#  39  Formaldehyde_solar_azimuth_angle                          79023 non-null  float64
#  40  Formaldehyde_sensor_zenith_angle                          79023 non-null  float64
#  41  Formaldehyde_sensor_azimuth_angle                         79023 non-null  float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    79023 non-null  float64
#  43  UvAerosolIndex_sensor_altitude                            79023 non-null  float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       79023 non-null  float64
#  45  UvAerosolIndex_sensor_zenith_angle                        79023 non-null  float64
#  46  UvAerosolIndex_solar_azimuth_angle                        79023 non-null  float64
#  47  UvAerosolIndex_solar_zenith_angle                         79023 non-null  float64
#  48  Ozone_O3_column_number_density                            79023 non-null  float64
#  49  Ozone_O3_column_number_density_amf                        79023 non-null  float64
#  50  Ozone_O3_slant_column_number_density                      79023 non-null  float64
#  51  Ozone_O3_effective_temperature                            79023 non-null  float64
#  52  Ozone_cloud_fraction                                      79023 non-null  float64
#  53  Ozone_sensor_azimuth_angle                                79023 non-null  float64
#  54  Ozone_sensor_zenith_angle                                 79023 non-null  float64
#  55  Ozone_solar_azimuth_angle                                 79023 non-null  float64
#  56  Ozone_solar_zenith_angle                                  79023 non-null  float64
#  57  UvAerosolLayerHeight_aerosol_height                       79023 non-null  float64
#  58  UvAerosolLayerHeight_aerosol_pressure                     79023 non-null  float64
#  59  UvAerosolLayerHeight_aerosol_optical_depth                79023 non-null  float64
#  60  UvAerosolLayerHeight_sensor_zenith_angle                  79023 non-null  float64
#  61  UvAerosolLayerHeight_sensor_azimuth_angle                 79023 non-null  float64
#  62  UvAerosolLayerHeight_solar_azimuth_angle                  79023 non-null  float64
#  63  UvAerosolLayerHeight_solar_zenith_angle                   79023 non-null  float64
#  64  Cloud_cloud_fraction                                      79023 non-null  float64
#  65  Cloud_cloud_top_pressure                                  79023 non-null  float64
#  66  Cloud_cloud_top_height                                    79023 non-null  float64
#  67  Cloud_cloud_base_pressure                                 79023 non-null  float64
#  68  Cloud_cloud_base_height                                   79023 non-null  float64
#  69  Cloud_cloud_optical_depth                                 79023 non-null  float64
#  70  Cloud_surface_albedo                                      79023 non-null  float64
#  71  Cloud_sensor_azimuth_angle                                79023 non-null  float64
#  72  Cloud_sensor_zenith_angle                                 79023 non-null  float64
#  73  Cloud_solar_azimuth_angle                                 79023 non-null  float64
#  74  Cloud_solar_zenith_angle                                  79023 non-null  float64
#  75  emission                                                  79023 non-null  float64
# dtypes: float64(73), int64(2), object(1)
# memory usage: 45.8+ MB

# %%
train.columns
# Out:
# Index(['ID_LAT_LON_YEAR_WEEK', 'latitude', 'longitude', 'year', 'week_no',
#        'SulphurDioxide_SO2_column_number_density',
#        'SulphurDioxide_SO2_column_number_density_amf',
#        'SulphurDioxide_SO2_slant_column_number_density',
#        'SulphurDioxide_cloud_fraction', 'SulphurDioxide_sensor_azimuth_angle',
#        'SulphurDioxide_sensor_zenith_angle',
#        'SulphurDioxide_solar_azimuth_angle',
#        'SulphurDioxide_solar_zenith_angle',
#        'SulphurDioxide_SO2_column_number_density_15km',
#        'CarbonMonoxide_CO_column_number_density',
#        'CarbonMonoxide_H2O_column_number_density',
#        'CarbonMonoxide_cloud_height', 'CarbonMonoxide_sensor_altitude',
#        'CarbonMonoxide_sensor_azimuth_angle',
#        'CarbonMonoxide_sensor_zenith_angle',
#        'CarbonMonoxide_solar_azimuth_angle',
#        'CarbonMonoxide_solar_zenith_angle',
#        'NitrogenDioxide_NO2_column_number_density',
#        'NitrogenDioxide_tropospheric_NO2_column_number_density',
#        'NitrogenDioxide_stratospheric_NO2_column_number_density',
#        'NitrogenDioxide_NO2_slant_column_number_density',
#        'NitrogenDioxide_tropopause_pressure',
#        'NitrogenDioxide_absorbing_aerosol_index',
#        'NitrogenDioxide_cloud_fraction', 'NitrogenDioxide_sensor_altitude',
#        'NitrogenDioxide_sensor_azimuth_angle',
#        'NitrogenDioxide_sensor_zenith_angle',
#        'NitrogenDioxide_solar_azimuth_angle',
#        'NitrogenDioxide_solar_zenith_angle',
#        'Formaldehyde_tropospheric_HCHO_column_number_density',
#        'Formaldehyde_tropospheric_HCHO_column_number_density_amf',
#        'Formaldehyde_HCHO_slant_column_number_density',
#        'Formaldehyde_cloud_fraction', 'Formaldehyde_solar_zenith_angle',
#        'Formaldehyde_solar_azimuth_angle', 'Formaldehyde_sensor_zenith_angle',
#        'Formaldehyde_sensor_azimuth_angle',
#        'UvAerosolIndex_absorbing_aerosol_index',
#        'UvAerosolIndex_sensor_altitude', 'UvAerosolIndex_sensor_azimuth_angle',
#        'UvAerosolIndex_sensor_zenith_angle',
#        'UvAerosolIndex_solar_azimuth_angle',
#        'UvAerosolIndex_solar_zenith_angle', 'Ozone_O3_column_number_density',
#        'Ozone_O3_column_number_density_amf',
#        'Ozone_O3_slant_column_number_density',
#        'Ozone_O3_effective_temperature', 'Ozone_cloud_fraction',
#        'Ozone_sensor_azimuth_angle', 'Ozone_sensor_zenith_angle',
#        'Ozone_solar_azimuth_angle', 'Ozone_solar_zenith_angle',
#        'UvAerosolLayerHeight_aerosol_height',
#        'UvAerosolLayerHeight_aerosol_pressure',
#        'UvAerosolLayerHeight_aerosol_optical_depth',
#        'UvAerosolLayerHeight_sensor_zenith_angle',
#        'UvAerosolLayerHeight_sensor_azimuth_angle',
#        'UvAerosolLayerHeight_solar_azimuth_angle',
#        'UvAerosolLayerHeight_solar_zenith_angle', 'Cloud_cloud_fraction',
#        'Cloud_cloud_top_pressure', 'Cloud_cloud_top_height',
#        'Cloud_cloud_base_pressure', 'Cloud_cloud_base_height',
#        'Cloud_cloud_optical_depth', 'Cloud_surface_albedo',
#        'Cloud_sensor_azimuth_angle', 'Cloud_sensor_zenith_angle',
#        'Cloud_solar_azimuth_angle', 'Cloud_solar_zenith_angle', 'emission'],
#       dtype='object')

# %%
X=train.drop(['ID_LAT_LON_YEAR_WEEK','emission'],axis=1)
y=train['emission']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((63218, 74), (15805, 74), (63218,), (15805,))

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([100.04355697,  53.87207053,  48.40632011, ...,  90.24852575,
#         81.38691986,  79.83590547])

# %%
model.score(X_test,y_test)
# Out:
# 0.03292820949023789

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 8742470314192565.0

# %% [markdown]
# # **Testing Part**

# %%
test=pd.read_csv('/kaggle/input/playground-series-s3e20/test.csv')
test.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2022_00     -0.51      29.29  2022        0
# 1  ID_-0.510_29.290_2022_01     -0.51      29.29  2022        1
# 2  ID_-0.510_29.290_2022_02     -0.51      29.29  2022        2
# 3  ID_-0.510_29.290_2022_03     -0.51      29.29  2022        3
# 4  ID_-0.510_29.290_2022_04     -0.51      29.29  2022        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                       NaN
# 1                                  0.000456
# 2                                  0.000161
# 3                                  0.000350
# 4                                 -0.000317
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                           NaN
# 1                                      0.691164
# 2                                      0.605107
# 3                                      0.696917
# 4                                      0.580527
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                             NaN
# 1                                        0.000316
# 2                                        0.000106
# 3                                        0.000243
# 4                                       -0.000184
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                            NaN                                  NaN  ...
# 1                       0.000000                            76.239196  ...
# 2                       0.079870                           -42.055341  ...
# 3                       0.201028                            72.169566  ...
# 4                       0.204352                            76.190865  ...
#
#    Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# 0              36022.027344             8472.313477
# 1              48539.737242             6476.147323
# 2              34133.080469             8984.795703
# 3              50854.991076             6014.724059
# 4              46594.685145             6849.280477
#
#    Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0               41047.937500              7472.313477
# 1               54915.708579              5476.147161
# 2               39006.093750              7984.795703
# 3               57646.368368              5014.724115
# 4               52896.541873              5849.280394
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   7.935617              0.240773
# 1                  11.448437              0.293119
# 2                  10.753179              0.267130
# 3                  11.764556              0.304679
# 4                  13.065317              0.284221
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                 -100.113792                  33.697044
# 1                  -30.510319                  42.402593
# 2                   39.087361                  45.936480
# 3                  -24.465127                  42.140419
# 4                  -12.907850                  30.122641
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                -133.047546                 33.779583
# 1                -138.632822                 31.012380
# 2                -144.784988                 26.743361
# 3                -135.027891                 29.604774
# 4                -135.500119                 26.276807
#
# [5 rows x 75 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24353 entries, 0 to 24352
# Data columns (total 75 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      24353 non-null  object
#  1   latitude                                                  24353 non-null  float64
#  2   longitude                                                 24353 non-null  float64
#  3   year                                                      24353 non-null  int64
#  4   week_no                                                   24353 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  18211 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              18211 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            18211 non-null  float64
#  8   SulphurDioxide_cloud_fraction                             18211 non-null  float64
#  9   SulphurDioxide_sensor_azimuth_angle                       18211 non-null  float64
#  10  SulphurDioxide_sensor_zenith_angle                        18211 non-null  float64
#  11  SulphurDioxide_solar_azimuth_angle                        18211 non-null  float64
#  12  SulphurDioxide_solar_zenith_angle                         18211 non-null  float64
#  13  SulphurDioxide_SO2_column_number_density_15km             18211 non-null  float64
#  14  CarbonMonoxide_CO_column_number_density                   23016 non-null  float64
#  15  CarbonMonoxide_H2O_column_number_density                  23016 non-null  float64
#  16  CarbonMonoxide_cloud_height                               23016 non-null  float64
#  17  CarbonMonoxide_sensor_altitude                            23016 non-null  float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       23016 non-null  float64
#  19  CarbonMonoxide_sensor_zenith_angle                        23016 non-null  float64
#  20  CarbonMonoxide_solar_azimuth_angle                        23016 non-null  float64
#  21  CarbonMonoxide_solar_zenith_angle                         23016 non-null  float64
#  22  NitrogenDioxide_NO2_column_number_density                 18698 non-null  float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    18698 non-null  float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   18698 non-null  float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           18698 non-null  float64
#  26  NitrogenDioxide_tropopause_pressure                       18698 non-null  float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   18698 non-null  float64
#  28  NitrogenDioxide_cloud_fraction                            18698 non-null  float64
#  29  NitrogenDioxide_sensor_altitude                           18698 non-null  float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      18698 non-null  float64
#  31  NitrogenDioxide_sensor_zenith_angle                       18698 non-null  float64
#  32  NitrogenDioxide_solar_azimuth_angle                       18698 non-null  float64
#  33  NitrogenDioxide_solar_zenith_angle                        18698 non-null  float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      20960 non-null  float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  20960 non-null  float64
#  36  Formaldehyde_HCHO_slant_column_number_density             20960 non-null  float64
#  37  Formaldehyde_cloud_fraction                               20960 non-null  float64
#  38  Formaldehyde_solar_zenith_angle                           20960 non-null  float64
#  39  Formaldehyde_solar_azimuth_angle                          20960 non-null  float64
#  40  Formaldehyde_sensor_zenith_angle                          20960 non-null  float64
#  41  Formaldehyde_sensor_azimuth_angle                         20960 non-null  float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    24206 non-null  float64
#  43  UvAerosolIndex_sensor_altitude                            24206 non-null  float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       24206 non-null  float64
#  45  UvAerosolIndex_sensor_zenith_angle                        24206 non-null  float64
#  46  UvAerosolIndex_solar_azimuth_angle                        24206 non-null  float64
#  47  UvAerosolIndex_solar_zenith_angle                         24206 non-null  float64
#  48  Ozone_O3_column_number_density                            24206 non-null  float64
#  49  Ozone_O3_column_number_density_amf                        24206 non-null  float64
#  50  Ozone_O3_slant_column_number_density                      24206 non-null  float64
#  51  Ozone_O3_effective_temperature                            24206 non-null  float64
#  52  Ozone_cloud_fraction                                      24206 non-null  float64
#  53  Ozone_sensor_azimuth_angle                                24206 non-null  float64
#  54  Ozone_sensor_zenith_angle                                 24206 non-null  float64
#  55  Ozone_solar_azimuth_angle                                 24206 non-null  float64
#  56  Ozone_solar_zenith_angle                                  24206 non-null  float64
#  57  UvAerosolLayerHeight_aerosol_height                       2093 non-null   float64
#  58  UvAerosolLayerHeight_aerosol_pressure                     2093 non-null   float64
#  59  UvAerosolLayerHeight_aerosol_optical_depth                2093 non-null   float64
#  60  UvAerosolLayerHeight_sensor_zenith_angle                  2093 non-null   float64
#  61  UvAerosolLayerHeight_sensor_azimuth_angle                 2093 non-null   float64
#  62  UvAerosolLayerHeight_solar_azimuth_angle                  2093 non-null   float64
#  63  UvAerosolLayerHeight_solar_zenith_angle                   2093 non-null   float64
#  64  Cloud_cloud_fraction                                      24187 non-null  float64
#  65  Cloud_cloud_top_pressure                                  24187 non-null  float64
#  66  Cloud_cloud_top_height                                    24187 non-null  float64
#  67  Cloud_cloud_base_pressure                                 24187 non-null  float64
#  68  Cloud_cloud_base_height                                   24187 non-null  float64
#  69  Cloud_cloud_optical_depth                                 24187 non-null  float64
#  70  Cloud_surface_albedo                                      24187 non-null  float64
#  71  Cloud_sensor_azimuth_angle                                24187 non-null  float64
#  72  Cloud_sensor_zenith_angle                                 24187 non-null  float64
#  73  Cloud_solar_azimuth_angle                                 24187 non-null  float64
#  74  Cloud_solar_zenith_angle                                  24187 non-null  float64
# dtypes: float64(72), int64(2), object(1)
# memory usage: 13.9+ MB

# %%
test=test.interpolate(method='linear',limit_direction='both')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24353 entries, 0 to 24352
# Data columns (total 75 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      24353 non-null  object
#  1   latitude                                                  24353 non-null  float64
#  2   longitude                                                 24353 non-null  float64
#  3   year                                                      24353 non-null  int64
#  4   week_no                                                   24353 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  24353 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              24353 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            24353 non-null  float64
#  8   SulphurDioxide_cloud_fraction                             24353 non-null  float64
#  9   SulphurDioxide_sensor_azimuth_angle                       24353 non-null  float64
#  10  SulphurDioxide_sensor_zenith_angle                        24353 non-null  float64
#  11  SulphurDioxide_solar_azimuth_angle                        24353 non-null  float64
#  12  SulphurDioxide_solar_zenith_angle                         24353 non-null  float64
#  13  SulphurDioxide_SO2_column_number_density_15km             24353 non-null  float64
#  14  CarbonMonoxide_CO_column_number_density                   24353 non-null  float64
#  15  CarbonMonoxide_H2O_column_number_density                  24353 non-null  float64
#  16  CarbonMonoxide_cloud_height                               24353 non-null  float64
#  17  CarbonMonoxide_sensor_altitude                            24353 non-null  float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       24353 non-null  float64
#  19  CarbonMonoxide_sensor_zenith_angle                        24353 non-null  float64
#  20  CarbonMonoxide_solar_azimuth_angle                        24353 non-null  float64
#  21  CarbonMonoxide_solar_zenith_angle                         24353 non-null  float64
#  22  NitrogenDioxide_NO2_column_number_density                 24353 non-null  float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    24353 non-null  float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   24353 non-null  float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           24353 non-null  float64
#  26  NitrogenDioxide_tropopause_pressure                       24353 non-null  float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   24353 non-null  float64
#  28  NitrogenDioxide_cloud_fraction                            24353 non-null  float64
#  29  NitrogenDioxide_sensor_altitude                           24353 non-null  float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      24353 non-null  float64
#  31  NitrogenDioxide_sensor_zenith_angle                       24353 non-null  float64
#  32  NitrogenDioxide_solar_azimuth_angle                       24353 non-null  float64
#  33  NitrogenDioxide_solar_zenith_angle                        24353 non-null  float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      24353 non-null  float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  24353 non-null  float64
#  36  Formaldehyde_HCHO_slant_column_number_density             24353 non-null  float64
#  37  Formaldehyde_cloud_fraction                               24353 non-null  float64
#  38  Formaldehyde_solar_zenith_angle                           24353 non-null  float64
#  39  Formaldehyde_solar_azimuth_angle                          24353 non-null  float64
#  40  Formaldehyde_sensor_zenith_angle                          24353 non-null  float64
#  41  Formaldehyde_sensor_azimuth_angle                         24353 non-null  float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    24353 non-null  float64
#  43  UvAerosolIndex_sensor_altitude                            24353 non-null  float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       24353 non-null  float64
#  45  UvAerosolIndex_sensor_zenith_angle                        24353 non-null  float64
#  46  UvAerosolIndex_solar_azimuth_angle                        24353 non-null  float64
#  47  UvAerosolIndex_solar_zenith_angle                         24353 non-null  float64
#  48  Ozone_O3_column_number_density                            24353 non-null  float64
#  49  Ozone_O3_column_number_density_amf                        24353 non-null  float64
#  50  Ozone_O3_slant_column_number_density                      24353 non-null  float64
#  51  Ozone_O3_effective_temperature                            24353 non-null  float64
#  52  Ozone_cloud_fraction                                      24353 non-null  float64
#  53  Ozone_sensor_azimuth_angle                                24353 non-null  float64
#  54  Ozone_sensor_zenith_angle                                 24353 non-null  float64
#  55  Ozone_solar_azimuth_angle                                 24353 non-null  float64
#  56  Ozone_solar_zenith_angle                                  24353 non-null  float64
#  57  UvAerosolLayerHeight_aerosol_height                       24353 non-null  float64
#  58  UvAerosolLayerHeight_aerosol_pressure                     24353 non-null  float64
#  59  UvAerosolLayerHeight_aerosol_optical_depth                24353 non-null  float64
#  60  UvAerosolLayerHeight_sensor_zenith_angle                  24353 non-null  float64
#  61  UvAerosolLayerHeight_sensor_azimuth_angle                 24353 non-null  float64
#  62  UvAerosolLayerHeight_solar_azimuth_angle                  24353 non-null  float64
#  63  UvAerosolLayerHeight_solar_zenith_angle                   24353 non-null  float64
#  64  Cloud_cloud_fraction                                      24353 non-null  float64
#  65  Cloud_cloud_top_pressure                                  24353 non-null  float64
#  66  Cloud_cloud_top_height                                    24353 non-null  float64
#  67  Cloud_cloud_base_pressure                                 24353 non-null  float64
#  68  Cloud_cloud_base_height                                   24353 non-null  float64
#  69  Cloud_cloud_optical_depth                                 24353 non-null  float64
#  70  Cloud_surface_albedo                                      24353 non-null  float64
#  71  Cloud_sensor_azimuth_angle                                24353 non-null  float64
#  72  Cloud_sensor_zenith_angle                                 24353 non-null  float64
#  73  Cloud_solar_azimuth_angle                                 24353 non-null  float64
#  74  Cloud_solar_zenith_angle                                  24353 non-null  float64
# dtypes: float64(72), int64(2), object(1)
# memory usage: 13.9+ MB

# %%
X_Test=test.drop(['ID_LAT_LON_YEAR_WEEK'],axis=1)

# %%
test['emission']=model.predict(X_Test)

# %%
test[['ID_LAT_LON_YEAR_WEEK','emission']].to_csv('submission.csv',index=False)
